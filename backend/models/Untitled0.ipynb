# %%
pip install google-api-python-client

# %%
from googleapiclient.discovery import build

# Replace with your API key
API_KEY = "AIzaSyDI3VMWo0MnXHrvEhXw34GtqAgc_5B6hiw"

# Initialize YouTube API client
youtube = build("youtube", "v3", developerKey=API_KEY)

def get_most_watched_videos(region="US", max_results=10):
    request = youtube.videos().list(
        part="snippet,statistics",
        chart="mostPopular",
        regionCode=region,
        maxResults=max_results
    )
    response = request.execute()

    videos = []
    for video in response["items"]:
        title = video["snippet"]["title"]
        views = video["statistics"]["viewCount"]
        url = f"https://www.youtube.com/watch?v={video['id']}"
        videos.append((title, views, url))

    return videos

# Fetch top videos
top_videos = get_most_watched_videos(region="IN", max_results=5)

# Display results
for idx, (title, views, url) in enumerate(top_videos, 1):
    print(f"{idx}. {title} - {views} views")
    print(f"   {url}\n")
# Out:
# 1. L2E Empuraan Trailer (Malayalam) | Mohanlal | Prithviraj Sukumaran | Murali Gopy | March 27 Release - 8272232 views
#    https://www.youtube.com/watch?v=PGqltBCo6cU
#
# 2. I Left Baby on Grandparents Door & Hid in our Home 😱 - 2452566 views
#    https://www.youtube.com/watch?v=buhiqHwHHNc
#
# 3. Aas Paas Episode 19 - [Eng Sub] - Laiba Khan - Ali Ansari - 20th March 2025 - HAR PAL GEO - 6350503 views
#    https://www.youtube.com/watch?v=FBHuy2DuxJE
#
# 4. OG SAMBAVAM Lyrical Video | Good Bad Ugly | Ajith | Trisha | G V Prakash | Adhik Ravichandran - 20239862 views
#    https://www.youtube.com/watch?v=kuZ-6jd82Go
#
# 5. Meem Se Mohabbat - Episode 28 [CC] 20th Mar 2025 - Sponsored By foodpanda, Master Paints, Skin White - 10539142 views
#    https://www.youtube.com/watch?v=4Q00U2V5Utg

# %%
from googleapiclient.discovery import build
import re
from collections import Counter

VIDEO_ID = "2Gg6Seob5Mg"  # Correct video ID


youtube = build("youtube", "v3", developerKey=API_KEY)

def extract_comments(video_id, max_comments=100):
    comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=max_comments,
        textFormat="plainText"
    )

    response = request.execute()

    for item in response["items"]:
        comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
        comments.append(comment)

    return comments

def extract_timestamps(comments):
    timestamps = []
    pattern = r"\b(\d{1,2}:\d{2})\b"  # Matches timestamps like 12:34 or 5:45

    for comment in comments:
        found = re.findall(pattern, comment)
        timestamps.extend(found)

    return Counter(timestamps).most_common(5)  # Get top 5 most mentioned timestamps

comments = extract_comments(VIDEO_ID)
popular_timestamps = extract_timestamps(comments)

print("Most mentioned timestamps in comments:")
for time, count in popular_timestamps:
    print(f"{time} - mentioned {count} times")
# Out:
# Most mentioned timestamps in comments:
# 1:20 - mentioned 1 times
# 0:50 - mentioned 1 times

# %%
import ffmpeg

# %%
import os
import re
import subprocess
from collections import Counter
from googleapiclient.discovery import build

VIDEO_ID = "2Gg6Seob5Mg"  # Correct video ID

youtube = build("youtube", "v3", developerKey=API_KEY)

def extract_comments(video_id, max_comments=100):
    comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=max_comments,
        textFormat="plainText"
    )

    response = request.execute()

    for item in response["items"]:
        comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
        comments.append(comment)

    return comments

def extract_timestamps(comments):
    timestamps = []
    pattern = r"\b(\d{1,2}:\d{2})\b"  # Matches timestamps like 12:34 or 5:45

    for comment in comments:
        found = re.findall(pattern, comment)
        timestamps.extend(found)

    return Counter(timestamps).most_common(5)  # Get top 5 most mentioned timestamps

def download_video(video_url, output_filename="video.mp4"):
    """Download YouTube video using yt-dlp."""
    command = [
        "yt-dlp",
        "-f", "best",  # Best quality available
        "-o", output_filename,
        video_url
    ]
    subprocess.run(command, check=True)
    print(f"Downloaded video as {output_filename}")

def resize_video(input_file, output_file, width=720, height=1280):
    """Resize video using ffmpeg."""
    command = [
        "ffmpeg",
        "-i", input_file,
        "-vf", f"scale={width}:{height}",
        "-c:a", "copy",
        output_file
    ]
    subprocess.run(command, check=True)
    print(f"Resized video saved as {output_file}")

# Extract most mentioned timestamps
comments = extract_comments(VIDEO_ID)
popular_timestamps = extract_timestamps(comments)

print("Most mentioned timestamps in comments:")
for time, count in popular_timestamps:
    print(f"{time} - mentioned {count} times")

# Download and resize video
video_url = f"https://www.youtube.com/watch?v={VIDEO_ID}"
download_video(video_url, "original.mp4")
resize_video("original.mp4", "resized.mp4", 720, 1280)
# Out:
# Most mentioned timestamps in comments:
# 1:20 - mentioned 1 times
# 0:50 - mentioned 1 times
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-2526217a11fa> in <cell line: 0>()
#      69 # Download and resize video
#      70 video_url = f"https://www.youtube.com/watch?v={VIDEO_ID}"
# ---> 71 download_video(video_url, "original.mp4")
#      72 resize_video("original.mp4", "resized.mp4", 720, 1280)
#
# <ipython-input-21-2526217a11fa> in download_video(video_url, output_filename)
#      44         video_url
#      45     ]
# ---> 46     subprocess.run(command, check=True)
#      47     print(f"Downloaded video as {output_filename}")
#      48
#
# /usr/lib/python3.11/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# ...
