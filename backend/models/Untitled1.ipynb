# %%
from googleapiclient.discovery import build

API_KEY = "AIzaSyDI3VMWo0MnXHrvEhXw34GtqAgc_5B6hiw"
VIDEO_ID = "Gt7se5OWLXw"

def get_youtube_comments(video_id, max_comments=50):
    youtube = build("youtube", "v3", developerKey=API_KEY)
    comments = []

    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=max_comments,
        textFormat="plainText"
    )
    response = request.execute()

    for item in response["items"]:
        comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
        comments.append(comment)

    return comments

comments = get_youtube_comments(VIDEO_ID)
print(comments[:5])  #
# Out:
# ["My Oscar Guzman business still won't load. Has had a glitch since day 1", 'Thanks!', "People don't care anymore about GTA 5 thankfully 🙏😎😎😎😎😎😎😎😎😎", 'R星的脑袋已经衰老无想了，GTA5线上再也不懂增加中国第六代战斗机，和你们美国的朱姆沃尔特战舰，了福特级航空母舰也不让购买了。新的超级的豪宅也不推出了。晚年了，反作弊这么强大，封杀了一切辅助。害的我们再也开不了辅助解锁，恢复，开辅助做任务，刷钱了。不应该这么严格，应该宽待一切辅助，允许我们刷金，再也不要封号了。。', 'Actually the regular sparrow is on sale. its the same exact price as the sea sparrow I restarted and just picked it up and was confused why it was only 1,089,000 but then I remembered the sea sparrow was on sale']

# %%
from transformers import pipeline

sentiment_pipeline = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")

results = sentiment_pipeline(comments[:10])
for comment, result in zip(comments[:10], results):
    print(f"Comment: {comment}\nSentiment: {result}\n")
# Out:
# Device set to use cpu
# Comment: My Oscar Guzman business still won't load. Has had a glitch since day 1
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9601466059684753}
#
# Comment: Thanks!
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998165965080261}
#
# Comment: People don't care anymore about GTA 5 thankfully 🙏😎😎😎😎😎😎😎😎😎
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9980158805847168}
#
# Comment: R星的脑袋已经衰老无想了，GTA5线上再也不懂增加中国第六代战斗机，和你们美国的朱姆沃尔特战舰，了福特级航空母舰也不让购买了。新的超级的豪宅也不推出了。晚年了，反作弊这么强大，封杀了一切辅助。害的我们再也开不了辅助解锁，恢复，开辅助做任务，刷钱了。不应该这么严格，应该宽待一切辅助，允许我们刷金，再也不要封号了。。
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9711323380470276}
#
# Comment: Actually the regular sparrow is on sale. its the same exact price as the sea sparrow I restarted and just picked it up and was confused why it was only 1,089,000 but then I remembered the sea sparrow was on sale
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9940698146820068}
#
# Comment: How much is the teraro
# ...

# %%
import pandas as pd

sentiments = sentiment_pipeline(comments)

df = pd.DataFrame({"Comment": comments, "Sentiment": [s["label"] for s in sentiments], "Score": [s["score"] for s in sentiments]})
df.to_csv("youtube_sentiments.csv", index=False)

print(df.head())
# Out:
#                                              Comment Sentiment     Score
# 0  My Oscar Guzman business still won't load. Has...  NEGATIVE  0.960147
# 1                                            Thanks!  POSITIVE  0.999817
# 2  People don't care anymore about GTA 5 thankful...  NEGATIVE  0.998016
# 3  R星的脑袋已经衰老无想了，GTA5线上再也不懂增加中国第六代战斗机，和你们美国的朱姆沃尔特战...  NEGATIVE  0.971132
# 4  Actually the regular sparrow is on sale. its t...  NEGATIVE  0.994070
